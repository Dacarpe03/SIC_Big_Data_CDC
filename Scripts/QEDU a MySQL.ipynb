# %%
import mysql.connector
import pandas as pd
import numpy as np
import re

# %%
mydb = mysql.connector.connect(
    host="localhost",
    user="student",
    password="student")
print(mydb)
# Out:
# <mysql.connector.connection.MySQLConnection object at 0x7feb5dd57310>

# %%
mycursor = mydb.cursor()
mycursor.execute("CREATE DATABASE IF NOT EXISTS proyecto_final")
mycursor.execute("USE proyecto_final")

# %%
mycursor.execute("CREATE TABLE IF NOT EXISTS Universidades (\
                id int AUTO_INCREMENT PRIMARY KEY, \
                nombre varchar(255), \
                url varchar(255), \
                tipo_centro varchar(255))")

# %%
mycursor.execute("CREATE TABLE IF NOT EXISTS Facultades (\
                id int AUTO_INCREMENT PRIMARY KEY, \
                nombre varchar(255), \
                id_univ int, \
                FOREIGN KEY (id_univ) REFERENCES Universidades(id) ON DELETE CASCADE ON UPDATE CASCADE)")

# %%
mycursor.execute("CREATE TABLE IF NOT EXISTS Grados (\
                id int AUTO_INCREMENT PRIMARY KEY, \
                id_fac int, \
                nombre varchar(255), \
                presencial bool, \
                nota_corte double, \
                idioma bool, \
                nota_corte_ant double, \
                nota_admision double, \
                rendimiento double, \
                creditos double, \
                precio_creditos double, \
                empleabilidad double, \
                FOREIGN KEY (id_fac) REFERENCES Facultades(id) ON DELETE CASCADE ON UPDATE CASCADE)")

# %%
mycursor.execute("SHOW TABLES")
for x in mycursor:
    print(x)
# Out:
# ('Facultades',)
# ('Grados',)
# ('Universidades',)

# %%
df = pd.read_csv("file:/home/student/Downloads/Datos_QEDU.csv")

# %%
df2 = df.replace(['Pública / Propio', 'Pública / Adscrito**'], 'Pública').replace(['Privada / Propio', 'Privada / Adscrito**'], 'Privada')
dfUniv = df2.groupby(['NOMBRE_UNIV', 'URL_INFO', 'TIPO_UNIV_CENTRO']).size().reset_index().iloc[:, :-1]
dfUniv
# Out:
#                                           NOMBRE_UNIV  \
# 0                                     Atlántico Medio
# 1                                   CUNEF Universidad
# 2                                    ESIC Universidad
# 3                                          Hesperides
# 4                                      IE Universidad
# ..                                                ...
# 83                            Universidad de la Rioja
# 84                   Universidad de las Illes Balears
# 85  Universidad del País Vasco/Euskal Herriko Unib...
# 86                         Universitat Abat Oliba CEU
# 87           Universitat de València (Estudi General)
#
#                                              URL_INFO TIPO_UNIV_CENTRO
# 0   https://www.universidadatlanticomedio.es/plane...          Privada
# 1         https://www.cunef.edu/estudios/cunef-grado/          Privada
# 2              https://www.esic.edu/university/grados          Privada
# 3                 https://hesperides.edu.es/estudios/          Privada
# 4   http://www.ie.edu/es/universidad/estudios/ofer...          Privada
# ..                                                ...              ...
# 83           https://www.unirioja.es/estudios/grados/          Pública
# 84                    http://estudis.uib.cat/es/grau/          Pública
# 85  https://www.ehu.eus/es/web/estudiosdegrado-gra...          Pública
# 86  https://www.uaoceu.es/estudios?tipos_estudio=3...          Privada
# 87  http://www.uv.es/uvweb/universidad/es/estudios...          Pública
#
# [88 rows x 3 columns]

# %%
sqlUniv = "INSERT INTO Universidades (nombre, url, tipo_centro) VALUES (%s, %s, %s)"
for index, row in dfUniv.iterrows():
    val = (row['NOMBRE_UNIV'], row['URL_INFO'], row['TIPO_UNIV_CENTRO'])
    mycursor.execute(sqlUniv, val)
mydb.commit()

# %%
dfFac = df2.groupby(['NOMBRE_UNIV', 'NOMBRE_CENTRO']).size().reset_index().iloc[:, :-1]
dfFac
# Out:
#                                    NOMBRE_UNIV  \
# 0                              Atlántico Medio
# 1                            CUNEF Universidad
# 2                            CUNEF Universidad
# 3                             ESIC Universidad
# 4                                   Hesperides
# ...                                        ...
# 1072  Universitat de València (Estudi General)
# 1073  Universitat de València (Estudi General)
# 1074  Universitat de València (Estudi General)
# 1075  Universitat de València (Estudi General)
# 1076  Universitat de València (Estudi General)
#
#                                           NOMBRE_CENTRO
# 0     Facultad de Ciencias Sociales y Jurídicas (Las...
# 1                 Escuela Politécnica Superior (Madrid)
# 2      Facultad de Empresa, Economía y Derecho (Madrid)
# 3     Facultad de Ciencias Jurídicas y Sociales (Mad...
# 4                        Escuela de Grados (Las Palmas)
# ...                                                 ...
# 1072      Facultad de Psicología y Logopedia (Valencia)
# 1073                     Facultad de Química (Valencia)
# 1074       Facultat d'Infermeria i Podologia (Valencia)
# 1075                Facultat de Fisioteràpia (Valencia)
# 1076                   Facultat de Magisteri (Valencia)
#
# [1077 rows x 2 columns]

# %%
sqlFac = "INSERT INTO Facultades (nombre, id_univ) VALUES (%s, %s)"
sqlQueryUniv = "SELECT id FROM Universidades WHERE nombre = %s"
uniAnterior = ""
idUni = -1
for index, row in dfFac.iterrows():
    uniActual = row['NOMBRE_UNIV']
    if uniAnterior != uniActual:
        mycursor.execute(sqlQueryUniv, (uniActual, ))
        myresult = mycursor.fetchall()
        idUni = myresult[0][0]
        uniAnterior = uniActual
    val = (row['NOMBRE_CENTRO'], idUni)
    mycursor.execute(sqlFac, val)
mydb.commit()

# %%
dfGrad = df2.groupby(['NOMBRE_UNIV', 'NOMBRE_CENTRO', 'NOM_TITULA', 'PRESENCIALIDAD', 'NOTA_CORTE', 'IDIOMAEXTRANJERO',
                      'NOTA_CORTE_ANT','NOTA_ADMISION', 'RENDIMIENTO',
                      'CREDITOS', 'PRECIO', 'TASA_AFIL']).size().reset_index().iloc[:, :-1]
dfGrad
# Out:
#                                    NOMBRE_UNIV  \
# 0            Universidad Autónoma de Barcelona
# 1            Universidad Autónoma de Barcelona
# 2            Universidad Autónoma de Barcelona
# 3            Universidad Autónoma de Barcelona
# 4            Universidad Autónoma de Barcelona
# ...                                        ...
# 1276  Universitat de València (Estudi General)
# 1277  Universitat de València (Estudi General)
# 1278  Universitat de València (Estudi General)
# 1279  Universitat de València (Estudi General)
# 1280  Universitat de València (Estudi General)
#
#                                           NOMBRE_CENTRO  \
# 0     Escuela Universitaria de Enfermería del Hospit...
# 1     Escuela Universitaria de Enfermería y Terapia ...
# 2                     Escuela de Ingeniería (Barcelona)
# 3                     Escuela de Ingeniería (Barcelona)
# 4                     Escuela de Ingeniería (Barcelona)
# ...                                                 ...
# 1276      Facultad de Psicología y Logopedia (Valencia)
# 1277      Facultad de Psicología y Logopedia (Valencia)
# 1278       Facultat d'Infermeria i Podologia (Valencia)
# 1279                   Facultat de Magisteri (Valencia)
# 1280                   Facultat de Magisteri (Valencia)
#
#                                     NOM_TITULA PRESENCIALIDAD  NOTA_CORTE  \
# 0                          Grado en Enfermería             Sí       10.03
# 1                          Grado en Enfermería             Sí        8.04
# 2                 Grado en Gestión Aeronáutica             Sí        5.15
# 3              Grado en Ingeniería Informática             Sí        9.70
# 4                  Grado en Ingeniería Química             Sí        8.97
# ...                                        ...            ...         ...
# 1276                        Grado en Logopedia             Sí        8.92
# 1277                       Grado en Psicología             Sí       10.43
# 1278                        Grado en Podología             Sí       11.03
# 1279  Grado en Maestro/a en Educación Infantil             Sí        9.59
# 1280  Grado en Maestro/a en Educación Primaria             Sí       10.04
#
#      IDIOMAEXTRANJERO  NOTA_CORTE_ANT  NOTA_ADMISION  RENDIMIENTO  CREDITOS  \
# 0                  No           10.76          11.18         95.0     240.0
# 1                  No            8.62           9.63         95.0     240.0
# 2                  No            7.77           9.42         85.0     240.0
# 3                  No            9.32          10.33         76.0     240.0
# 4                  No            8.52          10.12         77.0     240.0
# ...               ...             ...            ...          ...       ...
# 1276               No            9.29           9.33         93.0     240.0
# 1277              Sí*           10.51          10.89         90.0     240.0
# 1278               No           11.08          11.08         87.0     240.0
# 1279               No            9.75          10.37         96.0     240.0
# 1280               No           10.22          11.13         95.0     240.0
#
#       PRECIO  TASA_AFIL
# 0      18.46       84.4
# 1      18.46       94.2
# 2      18.46       80.5
# 3      18.46       84.2
# 4      18.46       79.5
# ...      ...        ...
# 1276   18.00       86.1
# 1277   14.03       60.5
# 1278   18.00       80.7
# 1279   12.79       77.1
# 1280   12.79       83.7
#
# [1281 rows x 12 columns]

# %%
sqlGrad = "INSERT INTO Grados (id_fac, nombre, presencial, nota_corte, idioma, \
                                    nota_corte_ant, nota_admision, rendimiento, creditos, precio_creditos, \
                                    empleabilidad) VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s, %s)"
sqlQueryFac = "SELECT id FROM Facultades WHERE id_univ = (SELECT id FROM Universidades WHERE nombre = %s) AND nombre = %s"
uniAnterior = ""
facAnterior = ""
idFac = -1
for index, row in dfGrad.iterrows():
    uniActual = row['NOMBRE_UNIV']
    facActual = row['NOMBRE_CENTRO']
    if uniAnterior != uniActual or facAnterior != facActual:
        mycursor.execute(sqlQueryFac, (uniActual, facActual))
        myresult = mycursor.fetchall()
        idFac = myresult[0][0]
        uniAnterior = uniActual
        facAnterior = facActual
    if row['PRESENCIALIDAD']=="No": 
        presencialidad=0 
    else: 
        presencialidad=1
    if row['IDIOMAEXTRANJERO']=="No":
        idioma=0 
    else: 
        idioma=1
    val = (idFac, row['NOM_TITULA'], presencialidad, row['NOTA_CORTE'], 
           idioma, row['NOTA_CORTE_ANT'], row['NOTA_ADMISION'], row['RENDIMIENTO'],
           row['CREDITOS'], row['PRECIO'], row['TASA_AFIL'])
    mycursor.execute(sqlGrad, val)
mydb.commit()

# %%
# Out:
# ('information_schema',)
# ('hive',)
# ('hue',)
# ('labs',)
# ('mysql',)
# ('performance_schema',)
# ('proyecto_final',)
# ('prueba1',)
# ('unis',)

# %%
# Out:
#                                                URL_INFO  \
# 0     https://www.unex.es/organizacion/servicios-uni...
# 1     https://www.unex.es/organizacion/servicios-uni...
# 2                             https://www.ubu.es/grados
# 3                 https://www.um.es/web/estudios/grados
# 4            https://web.ua.es/es/grados-oficiales.html
# ...                                                 ...
# 3631             http://www.unir.net/grados-online.aspx
# 3632                  http://estudios.uoc.edu/es/grados
# 3633  http://www.ub.edu/dyn/cms/continguts_es/estudi...
# 3634                  http://www.usj.es/estudios/grados
# 3635         https://www.ucv.es/oferta-academica/grados
#
#                                              NOM_TITULA  \
# 0                             Grado en Educación Social
# 1        Grado en Ingeniería Mecánica (Rama Industrial)
# 2                                      Grado en Derecho
# 3                  Grado en Traducción e Interpretación
# 4                                      Grado en Derecho
# ...                                                 ...
# 3631                         Grado en Historia del Arte
# 3632    Grado en Administración y Dirección de Empresas
# 3633  Grado en Diseño y Desarrollo de Videojuegos y ...
# 3634                              Grado en Criminología
# 3635                                  Grado en Historia
#
#                                             NOMBRE_UNIV  \
# 0                            Universidad de Extremadura
# 1                            Universidad de Extremadura
# 2                                 Universidad de Burgos
# 3                                 Universidad de Murcia
# 4                               Universidad de Alicante
# ...                                                 ...
# 3631              Universidad Internacional de la Rioja
# 3632                    Universidad Oberta de Catalunya
# 3633                           Universidad de Barcelona
# 3634                              Universidad San Jorge
# 3635  Universidad Católica de Valencia San Vicente M...
#
#                                           NOMBRE_CENTRO      TIPO_UNIV_CENTRO  \
# 0       Facultad de Formación del Profesorado (Cáceres)      Pública / Propio
# 1         Escuela de Ingenierías Industriales (Badajoz)      Pública / Propio
# 2                          Facultad de Derecho (Burgos)      Pública / Propio
# 3                           Facultad de Letras (Murcia)      Pública / Propio
# 4                        Facultad de Derecho (Alicante)      Pública / Propio
# ...                                                 ...                   ...
# 3631  Facultad de Ciencias Sociales y Humanidades (L...      Privada / Propio
# 3632        Universitat Oberta de Catalunya (Barcelona)      Privada / Propio
# 3633  ENTI - Escuela de Nuevas Tecnologías Interacti...  Pública / Adscrito**
# 3634  Facultad de Comunicación y Ciencias Sociales (...      Privada / Propio
# 3635  Facultad de Filosofía, Letras y Humanidades (V...      Privada / Propio
#
#      PRESENCIALIDAD IDIOMAEXTRANJERO  PLAZAS  NOTA_CORTE  NOTA_CORTE_ANT  \
# 0                Sí               No    65.0        5.93            8.13
# 1                Sí               No    75.0        6.55            6.00
# 2                Sí               No    80.0        5.00            5.00
# 3                Sí               No   100.0        7.66            7.39
# 4                Sí              Sí*   240.0        9.11            9.55
# ...             ...              ...     ...         ...             ...
# 3631             No               No     NaN         NaN             NaN
# 3632             Sí               No  1800.0         NaN             NaN
# 3633              -               No     NaN         NaN             NaN
# 3634              -               No     NaN         NaN             NaN
# 3635              -               No     NaN         NaN             NaN
#
#       NOTA_ADMISION  RENDIMIENTO  CREDITOS  PRECIO  TASA_AFIL
# 0             10.40         95.0     240.0   11.82       56.2
# 1              9.99         57.0     240.0   16.13       92.5
# 2              7.51         70.0     240.0   12.59       41.7
# 3             12.06         90.0     240.0   14.38        NaN
# 4             10.06         80.0     240.0   11.84       52.5
# ...             ...          ...       ...     ...        ...
# 3631            NaN          NaN     240.0     NaN        NaN
# 3632            NaN          NaN     240.0     NaN        NaN
# 3633            NaN          NaN     240.0     NaN        NaN
# 3634            NaN          NaN     240.0     NaN        NaN
# 3635            NaN          NaN     240.0     NaN        NaN
#
# [3636 rows x 15 columns]

# %%
# Out:
# 233
